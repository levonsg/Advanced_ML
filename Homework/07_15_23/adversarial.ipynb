# %% [markdown]
# ### Generating human faces with Adversarial Networks
# <img src="https://www.strangerdimensions.com/wp-content/uploads/2013/11/reception-robot.jpg" width=320>
# This time we'll train a neural net to generate plausible human faces in all their subtlty: appearance, expression, accessories, etc.
#
# Based on https://github.com/Lasagne/Recipes/pull/94 .

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
plt.rcParams.update({'axes.titlesize': 'small'})

from sklearn.datasets import load_digits
#The following line fetches you two datasets: images, usable for autoencoder training and attributes.
from lfw_dataset import fetch_lfw_dataset
data,attrs = fetch_lfw_dataset(dimx=36,dimy=36)

#preprocess faces
data = np.float32(data)/255.

IMG_SHAPE = data.shape[1:]

# %%
#print random image
plt.imshow(data[np.random.randint(data.shape[0])], cmap="gray", interpolation="none")

# %% [markdown]
# # Generative adversarial nets 101
#
# <img src="https://raw.githubusercontent.com/torch/torch.github.io/master/blog/_posts/images/model.png" width=320px height=240px>
#
# Deep learning is simple, isn't it?
# * build some network that generates the face (small image)
# * make up a __measure__ of __how good that face is__
# * optimize with gradient descent
#
#
# The only problem is: how can we tell well-generated faces from bad?
#
# __If we can't tell good faces from bad, we delegate it to yet another neural network!__
#
# That makes the two of them:
# * __G__enerator - takes random noize for inspiration and tries to generate a face sample.
#   * Let's call him __G__(z), where z is a gaussian noize.
# * __D__iscriminator - takes a face sample and tries to tell if it's great or fake.
#   * Predicts the probability of input image being a __real face__
#   * Let's call him __D__(x), x being an image.
#   * __D(x)__ is a predition for real image and __D(G(z))__ is prediction for the face made by generator.
#
# Before we dive into training them, let's construct the two networks.

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras import layers as L

# %%
CODE_SIZE = 256

generator = Sequential()
generator.add(L.InputLayer([CODE_SIZE],name='noise'))
generator.add(L.Dense(10*8*8, activation='elu'))

generator.add(L.Reshape((8,8,10)))
generator.add(L.Conv2DTranspose(256,kernel_size=(5,5),activation='elu'))
generator.add(L.Conv2DTranspose(128,kernel_size=(5,5),activation='elu'))
generator.add(L.UpSampling2D(size=(2,2)))
generator.add(L.Conv2DTranspose(64,kernel_size=3,activation='elu'))
generator.add(L.Conv2DTranspose(32,kernel_size=3,activation='elu'))
generator.add(L.Conv2DTranspose(32,kernel_size=3,activation='elu'))
generator.add(L.Conv2D(3,kernel_size=3,activation='elu'))
# generator.build(input_shape=(None, 256))
# generator.summary()

# %%
assert generator.output_shape[1:] == IMG_SHAPE, "generator must output an image of shape %s, but instead it produces %s"%(IMG_SHAPE,generator.output_shape[1:])

# %% [markdown]
# ### Discriminator
# Discriminator is your usual convolutional network with interlooping convolution and pooling layers

# %%
discriminator = Sequential()

discriminator.add(L.InputLayer(IMG_SHAPE))

discriminator.add(L.Dense(units=512,input_dim=28*28))
discriminator.add(L.Conv2D(64, (3,3), strides =(1,1), padding ='same', input_shape = [28,28,1]))
discriminator.add(L.LeakyReLU(0.2))
discriminator.add(L.Dropout(0.3))

discriminator.add(L.Flatten())
discriminator.add(L.Dense(256,activation='tanh'))
discriminator.add(L.Dense(2,activation=tf.nn.log_softmax))

# %% [markdown]
# # Training
#
# We train the two networks concurrently:
# * Train __discriminator__ to better distinguish real data from __current__ generator
# * Train __generator__ to make discriminator think generator is real
#
# ![img](gan.png)
#
# Training is done iteratively until discriminator is no longer able to find the difference (or until you run out of patience).
#
#
# ### Tricks:
# * You can find useful tricks here https://github.com/soumith/ganhacks

# %% [markdown]
# ### Auxilary functions
# Here we define a few helper functions that draw current data distributions and sample training batches.

# %%
def sample_noise_batch(bsize):
    return np.random.normal(size=(bsize, CODE_SIZE)).astype('float32')

def sample_data_batch(bsize):
    idxs = np.random.choice(np.arange(data.shape[0]), size=bsize)
    return data[idxs]

def sample_images(nrow,ncol, sharp=False):
    images = generator.predict(sample_noise_batch(bsize=nrow*ncol))
    if np.var(images)!=0:
        images = images.clip(np.min(data),np.max(data))
    for i in range(nrow*ncol):
        plt.subplot(nrow,ncol,i+1)
        if sharp:
            plt.imshow(images[i].reshape(IMG_SHAPE),cmap="gray", interpolation="none")
        else:
            plt.imshow(images[i].reshape(IMG_SHAPE),cmap="gray")
    plt.show()

def sample_probas(bsize):
    plt.title('Generated vs real data')
    plt.hist(np.exp(discriminator.predict(sample_data_batch(bsize)))[:,1],
             label='D(x)', alpha=0.5,range=[0,1])
    plt.hist(np.exp(discriminator.predict(generator.predict(sample_noise_batch(bsize))))[:,1],
             label='D(G(z))',alpha=0.5,range=[0,1])
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# ### Training
# Main loop.
# We just train generator and discriminator in a loop and draw results once every N iterations.

# %%
disc_optimizer = tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5)
gen_optimizer = tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5)

# %%
from IPython import display
from tqdm import tnrange
bsize=256

for epoch in tnrange(50000):
    real_data = sample_data_batch(bsize)
    noise = sample_noise_batch(bsize)

    for i in range(5):
    ########################
    #discriminator training#
    ########################
        with tf.GradientTape() as tape:
            logp_real = discriminator(real_data)
            generated_data = generator(noise)
            logp_gen = discriminator(generated_data)
    
            d_loss = -tf.reduce_mean(logp_real[:, 1] + logp_gen[:, 0])
            d_loss += tf.reduce_mean(discriminator.layers[-1].kernel ** 2)

        gradients = tape.gradient(d_loss, discriminator.trainable_weights)
        disc_optimizer.apply_gradients(zip(gradients, discriminator.trainable_weights))
    ########################
    ###generator training###
    ########################

    with tf.GradientTape() as tape:
        
        
        g_loss = -tf.reduce_mean(generator.layers[-1].kernel)

    gradients = tape.gradient(g_loss, generator.trainable_variables)
    gen_optimizer.apply_gradients(zip(gradients, generator.trainable_variables))
    print("###################################################################")
    print('g_loss', g_loss)
    print('d_loss', d_loss)
    print('epoch', epoch)
    
    print("*******************************************************************")
    if epoch %100==0:
        display.clear_output(wait=True)
        sample_images(2,3,True)
        sample_probas(1000)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 32/32 [==============================] - 0s 3ms/step
# 32/32 [==============================] - 0s 3ms/step
# 32/32 [==============================] - 0s 3ms/step
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.5578165, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047491182, shape=(), dtype=float32)
# epoch 3001
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.5580165, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0004740734, shape=(), dtype=float32)
# epoch 3002
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.5582164, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047390902, shape=(), dtype=float32)
# epoch 3003
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.5584164, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047404337, shape=(), dtype=float32)
# epoch 3004
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.5586164, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047396362, shape=(), dtype=float32)
# epoch 3005
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.5588164, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047420425, shape=(), dtype=float32)
# epoch 3006
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.5590163, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047391996, shape=(), dtype=float32)
# epoch 3007
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.5592163, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047389252, shape=(), dtype=float32)
# epoch 3008
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.5594163, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047452142, shape=(), dtype=float32)
# epoch 3009
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.5596163, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0004776839, shape=(), dtype=float32)
# epoch 3010
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.55981624, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00048299416, shape=(), dtype=float32)
# epoch 3011
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.5600162, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0004747055, shape=(), dtype=float32)
# epoch 3012
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.5602162, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047385026, shape=(), dtype=float32)
# epoch 3013
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.56041616, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047879442, shape=(), dtype=float32)
# epoch 3014
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.5606161, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0007701671, shape=(), dtype=float32)
# epoch 3015
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.5608161, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047436828, shape=(), dtype=float32)
# epoch 3016
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.561016, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047396528, shape=(), dtype=float32)
# epoch 3017
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.56121606, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047413644, shape=(), dtype=float32)
# epoch 3018
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.561416, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047434538, shape=(), dtype=float32)
# epoch 3019
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.561616, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0004759827, shape=(), dtype=float32)
# epoch 3020
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.5618159, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0004744329, shape=(), dtype=float32)
# epoch 3021
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.56201595, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047401883, shape=(), dtype=float32)
# epoch 3022
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.56221586, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047391508, shape=(), dtype=float32)
# epoch 3023
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.56241584, shape=(), dtype=float32)
# d_loss tf.Tensor(0.000473994, shape=(), dtype=float32)
# epoch 3024
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.5626159, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047651608, shape=(), dtype=float32)
# epoch 3025
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.56281585, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047394962, shape=(), dtype=float32)
# epoch 3026
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.56301576, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00047403947, shape=(), dtype=float32)
# epoch 3027
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.56321573, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0004746917, shape=(), dtype=float32)
# epoch 3028
# *******************************************************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_37508\390884177.py in ?()
#      15     #discriminator training#
#      16     ########################
#      17         with tf.GradientTape() as tape:
#      18             logp_real = discriminator(real_data)
# ---> 19             generated_data = generator(noise)
#      20             logp_gen = discriminator(generated_data)
#      21
#      22             d_loss = -tf.reduce_mean(logp_real[:, 1] + logp_gen[:, 0])
#
# ~\.conda\envs\tf_39\lib\site-packages\keras\utils\traceback_utils.py in ?(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#      67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
# ---> 69       del filtered_tb
#
# ~\.conda\envs\tf_39\lib\site-packages\keras\engine\training.py in ?(self, *args, **kwargs)
#     486         super().__call__(inputs, *copied_args, **copied_kwargs)
#     487
#     488       layout_map_lib._map_subclass_model_variable(self, self._layout_map)
#     489
# --> 490     return super().__call__(*args, **kwargs)
#
# ~\.conda\envs\tf_39\lib\site-packages\keras\utils\traceback_utils.py in ?(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#      67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
# ---> 69       del filtered_tb
#
# ~\.conda\envs\tf_39\lib\site-packages\keras\engine\base_layer.py in ?(self, *args, **kwargs)
#    1019           self._set_mask_metadata(inputs, outputs, input_masks, not eager)
#    1020         if self._saved_model_inputs_spec is None:
#    1021           self._set_save_spec(inputs, args, kwargs)
#    1022
# -> 1023         return outputs
#
# ~\.conda\envs\tf_39\lib\site-packages\keras\utils\traceback_utils.py in ?(*args, **kwargs)
#     145         new_e = e
#     146       raise new_e.with_traceback(e.__traceback__) from None
#     147     finally:
#     148       del signature
# --> 149       del bound_signature
#
# ~\.conda\envs\tf_39\lib\site-packages\keras\engine\sequential.py in ?(self, inputs, training, mask)
#     370
#     371     if self._graph_initialized:
#     372       if not self.built:
#     373         self._init_graph_network(self.inputs, self.outputs)
# --> 374       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     375
#     376     outputs = inputs  # handle the corner case where self.layers is empty
#     377     for layer in self.layers:
#
# ~\.conda\envs\tf_39\lib\site-packages\keras\engine\functional.py in ?(self, inputs, training, mask)
#     454     Returns:
#     455         A tensor if there is a single output, or
#     456         a list of tensors if there are more than one outputs.
#     457     """
# --> 458     return self._run_internal_graph(
#     459         inputs, training=training, mask=mask)
#
# ~\.conda\envs\tf_39\lib\site-packages\keras\engine\functional.py in ?(self, inputs, training, mask)
#     592         if any(t_id not in tensor_dict for t_id in node.flat_input_ids):
#     593           continue  # Node is not computable, try skipping.
#     594
#     595         args, kwargs = node.map_arguments(tensor_dict)
# --> 596         outputs = node.layer(*args, **kwargs)
#     597
#     598         # Update tensor_dict.
#     599         for x_id, y in zip(node.flat_output_ids, tf.nest.flatten(outputs)):
#
# ~\.conda\envs\tf_39\lib\site-packages\keras\utils\traceback_utils.py in ?(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#      67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
# ---> 69       del filtered_tb
#
# ~\.conda\envs\tf_39\lib\site-packages\keras\engine\base_layer.py in ?(self, *args, **kwargs)
#    1019           self._set_mask_metadata(inputs, outputs, input_masks, not eager)
#    1020         if self._saved_model_inputs_spec is None:
#    1021           self._set_save_spec(inputs, args, kwargs)
#    1022
# -> 1023         return outputs
#
# ~\.conda\envs\tf_39\lib\site-packages\keras\utils\traceback_utils.py in ?(*args, **kwargs)
#     145         new_e = e
#     146       raise new_e.with_traceback(e.__traceback__) from None
#     147     finally:
#     148       del signature
# --> 149       del bound_signature
#
# ~\.conda\envs\tf_39\lib\site-packages\keras\layers\core\dense.py in ?(self, inputs)
#     231     if self.use_bias:
#     232       outputs = tf.nn.bias_add(outputs, self.bias)
#     233
#     234     if self.activation is not None:
# --> 235       outputs = self.activation(outputs)
#     236
#     237     if is_ragged:
#     238       outputs = original_inputs.with_flat_values(outputs)
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1180         result = dispatch(op_dispatch_handler, args, kwargs)
#    1181         if result is not OpDispatcher.NOT_SUPPORTED:
#    1182           return result
#    1183         else:
# -> 1184           raise
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\nn_ops.py in ?(logits, axis, name)
#    3967       dimension of `logits`.
#    3968   """
#    3969   if axis is None:
#    3970     axis = -1
# -> 3971   return _wrap_2d_function(logits, gen_nn_ops.log_softmax, axis, name)
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\nn_ops.py in ?(inputs, compute_op, dim, name)
#    3812   shape = inputs.get_shape()
#    3813   is_last_dim = (dim == -1) or (dim == shape.ndims - 1)
#    3814
#    3815   if is_last_dim:
# -> 3816     return compute_op(inputs, name=name)
#    3817
#    3818   dim_val = dim
#    3819   if isinstance(dim, ops.Tensor):
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\gen_nn_ops.py in ?(logits, name)
#    5468       return _result
#    5469     except _core._NotOkStatusException as e:
#    5470       _ops.raise_from_not_ok_status(e, name)
#    5471     except _core._FallbackException:
# -> 5472       pass
#    5473     try:
#    5474       return log_softmax_eager_fallback(
#    5475           logits, name=name, ctx=_ctx)
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=[16,24])
sample_images(16,8)

# %%
disc_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

for i in range(5):
    with tf.GradientTape() as tape:
        logp_real = discriminator(real_data)
        generated_data = generator(noise)
        logp_gen = discriminator(generated_data)

        d_loss = -tf.reduce_mean(logp_real[:, 1] + logp_gen[:, 0])
        d_loss += tf.reduce_mean(discriminator.layers[-1].kernel ** 2)

    gradients = tape.gradient(d_loss, discriminator.trainable_weights)
    disc_optimizer.apply_gradients(zip(gradients, discriminator.trainable_weights))
