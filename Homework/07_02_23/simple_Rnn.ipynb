# %%
import numpy as np


class DataReader:
    def __init__(self, path, seq_length):
        self.fp = open(path, "r")        
        self.data = self.fp.read()
        chars = list(set(self.data))
        self.char_to_ix = {ch:i for (i,ch) in enumerate(chars)}
        self.ix_to_char = {i:ch for (i,ch) in enumerate(chars)}
        self.data_size = len(self.data)
        self.vocab_size = len(chars)
        self.pointer = 0
        self.seq_length = seq_length

    def next_batch(self):
        input_start = self.pointer
        input_end = self.pointer + self.seq_length
        inputs = [self.char_to_ix[ch] for ch in self.data[input_start:input_end]]
        targets = [self.char_to_ix[ch] for ch in self.data[input_start+1:input_end+1]]
        self.pointer += self.seq_length
        if self.pointer + self.seq_length + 1 >= self.data_size:
            self.pointer = 0
        return inputs, targets

    def just_started(self):
        return self.pointer == 0

    def close(self):
        self.fp.close()

# %%
class RNN:
    def __init__(self, hidden_size, vocab_size, seq_length, learning_rate):
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.seq_length = seq_length
        self.learning_rate = learning_rate
        self.U = np.random.uniform(-np.sqrt(1./vocab_size), np.sqrt(1./vocab_size), (hidden_size, vocab_size))
        self.V = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (vocab_size, hidden_size))
        self.W = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (hidden_size, hidden_size))
        self.b = np.zeros((hidden_size, 1))
        self.c = np.zeros((vocab_size, 1)) 
        self.mU = np.zeros_like(self.U)
        self.mW = np.zeros_like(self.W)
        self.mV = np.zeros_like(self.V)
        self.mb = np.zeros_like(self.b)
        self.mc = np.zeros_like(self.c)

    def softmax(self, x):
        p = np.exp(x- np.max(x))
        return p / np.sum(p)
        
    def forward(self, inputs, hprev):
            xs, hs, os, ycap = {}, {}, {}, {}
            hs[-1] = np.copy(hprev)
            for t in range(len(inputs)):
                xs[t] = np.zeros((self.vocab_size,1))
                xs[t][inputs[t]] = 1
                hs[t] = np.tanh(np.dot(self.U,xs[t]) + np.dot(self.W,hs[t-1]) + self.b)
                os[t] = np.dot(self.V,hs[t]) + self.c 
                ycap[t] = self.softmax(os[t])
            return xs, hs, ycap
        
    def backward(self, xs, hs, ps, targets):

            dU, dW, dV = np.zeros_like(self.U), np.zeros_like(self.W), np.zeros_like(self.V)
            db, dc = np.zeros_like(self.b), np.zeros_like(self.c)
            dhnext = np.zeros_like(hs[0])
            for t in reversed(range(self.seq_length)):       
                dy = np.copy(ps[t])
                dy[targets[t]] -= 1 
                dV += np.dot(dy, hs[t].T)
                dc +=dy # need to check
                dh = np.dot(self.V.T, dy) + dhnext 
                dhrec = (1 - hs[t] * hs[t]) * dh 
                db += dhrec
                dU += np.dot(dhrec, xs[t].T)
                dW += np.dot(dhrec, hs[t-1].T)
                dhnext = np.dot(self.W.T, dhrec)
            for dparam in [dU, dW, dV, db, dc]:
                np.clip(dparam, -5, 5, out=dparam) 
            return dU, dW, dV, db, dc
    
    def loss(self, ps, targets):
            return sum(-np.log(ps[t][targets[t],0]) for t in range(self.seq_length))      
    
    def update_model(self, dU, dW, dV, db, dc):
        for param, dparam, mem in zip([self.U, self.W, self.V, self.b, self.c],
                                  [dU, dW, dV, db, dc],
                                  [self.mU, self.mW, self.mV, self.mb, self.mc]):
            mem += dparam*dparam
            param += -self.learning_rate*dparam/np.sqrt(mem+1e-8)
                
                
    def sample(self, h, seed_ix, n):
            x = np.zeros((self.vocab_size, 1))
            x[seed_ix] = 1
            ixes = []
            for t in range(n):
                h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
                y = np.dot(self.V, h) + self.c
                p = np.exp(y)/np.sum(np.exp(y))
                ix = np.random.choice(range(self.vocab_size), p = p.ravel())
                x = np.zeros((self.vocab_size,1))
                x[ix] = 1
                ixes.append(ix)
            return ixes

    def train(self, data_reader):
            iter_num = 0
            threshold = 5
            smooth_loss = -np.log(1.0/data_reader.vocab_size)*self.seq_length
            while (smooth_loss > threshold):
                if data_reader.just_started():
                    hprev = np.zeros((self.hidden_size,1))
                inputs, targets = data_reader.next_batch()
                xs, hs, ps = self.forward(inputs, hprev)
                dU, dW, dV, db, dc = self.backward(xs, hs, ps, targets)
                loss = self.loss(ps, targets)
                self.update_model(dU, dW, dV, db, dc)
                smooth_loss = smooth_loss*0.999 + loss*0.001
                hprev = hs[self.seq_length-1]
                if not iter_num%500:
                    sample_ix = self.sample(hprev, inputs[0], 200)
                    print( ''.join(data_reader.ix_to_char[ix] for ix in sample_ix))
                    print( "\n\niter :%d, loss:%f"%(iter_num, smooth_loss))
                iter_num += 1

    def predict(self, data_reader, start, n):
        x = np.zeros((self.vocab_size, 1))
        chars = [ch for ch in start]
        ixes = []
        for i in range(len(chars)):
            ix = data_reader.char_to_ix[chars[i]]
            x[ix] = 1
            ixes.append(ix)
        h = np.zeros((self.hidden_size,1))
        for t in range(n):
            h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
            y = np.dot(self.V, h) + self.c
            p = np.exp(y)/np.sum(np.exp(y))
            ix = np.random.choice(range(self.vocab_size), p = p.ravel())
            x = np.zeros((self.vocab_size,1))
            x[ix] = 1
            ixes.append(ix)
        txt = ''.join(data_reader.ix_to_char[i] for i in ixes)
        return txt

# %%
data_reader = DataReader("input.txt", seq_length)

# %%
seq_length = 20
#read text from the "input.txt" file
data_reader = DataReader("input.txt", seq_length)
rnn = RNN(hidden_size=100, vocab_size=data_reader.vocab_size,seq_length=seq_length,learning_rate=1e-1)
rnn.train(data_reader)
# Out:
# eHuwr at abfn& nHl2:an0 DnDn  nwunrDJ: w;:TSn;e   !r&wf . 0 MbhSrsL tnpwgnk wosn9E   rJ s&f-wna 1 Daa,I dd c.b'S n2 M x:nNmaOg1o  ns antNEs upT;e  nn in InIwanna v sMl ra gay09C“na!y
# Dc2    n  i PoaB
#
#
# iter :0, loss:81.550511
# wo lot rorae tuIo  li1 see  ra e tc soul l r rep wnth beid tori !e e l Ho s t our, atoug fbn if avss wd oon  .e t
#   be oroerlhdr thee re
#  tse wo e rofwiu loh s he  t nbaner mr foe âlul w ey wo seermd
#
#
# iter :500, loss:74.459109
# fe doomde  cloogar, wrtt weme no! tyre doâ her, thenhe hillehoendomer inrwe bimee sinoefes romee eaU nane f tas to iafra ;efer faeme nos ah who deoave cidonfouwe filvitopg woade0k2bhe, cyoadgdt“ Wuaw
#
#
# iter :1000, loss:66.116934
# Bpbilvo Saboutinly thin alte marnga Cond the, ta thend tte,. Ad wot mipxolheor
# T9 and tSd and anm th fot an, wouseiund ,asscand mad amee hasame, the tegresthey Ahetiley plin thimsh,in ptoâmer alfeeve
#
#
# iter :1500, loss:58.719228
#  tople tor mand taghme th. in woub. peime tethed msy tata d bhiptibs.idy wa:n is he wad sasegh. wiche al an ftithime wesoferindte siws wuthig, lazy, ra gott the Cand lout he Ll wnmans. ha poad tised t
#
#
# iter :2000, loss:52.903854
#  ilBilin ald nna walles, Of thes Ap: herill Hehed taed thet sawl the bomimhitt asaf te tpeelt thede Alrs nt angsa bavt. wed ind wid wo at if br siwll puma aid cofouen wherey suo€,
# chewthworin foxcuinf
#
#
# iter :2500, loss:48.270771
# s, fior apstorcheit, sas. Thin , rar ix an aln indsimol' w ac it ilf threrd owbs orsisr runsit map san: llây theomthes De hlrt and orree bibo Co afery foung the pind zhem VoDsa sa at e bil 29resro kiz
#
#
# iter :3000, loss:44.604108
# op camete!, wad cuna lapgeind pxehe Anomer An time y, bucdient and an asreed: ots She and maled clf imed sedy thes uls marhitg ctost Sa bom the caprtle audimed cton dim Sloun at ans thiuvey. ang burt
#
#
# iter :3500, loss:41.505970
# d him Ia ped rois dH. w,is Caoin tire has cail then sand ind th kit himg lnis, we toty. - annig toon ntd cam hi sthe dook ars he  anv. wail wa t wneen. The bas soil. fort ais, his. Oll and wind the do
#
#
# iter :4000, loss:38.992296
# es op Se and in ind ha the plivena deesey chourteens and anht ay roraid tabarntre thifa liadn, tis puthied bute and insaid tus ant bors,
#
# Intote undien. Alb laid ther. He hipure gused then and cablir.
#
#
# iter :4500, loss:36.912104
# re dirm..
#
# In an tover Alidd unse atriop tosk, âOce aor ab!. To forishedred coin on ined thed cime as ans of trore t ftea doit all. On chirt op Ali Baba, dwis wind toof fist. fy in cooc to He Cwes wro
#
#
# iter :5000, loss:35.407887
# e same a d ing toom to fom intin and the came, hed foug to himsin tort Alo to thel Ali Bald sith nogr treed in san dut torren ano, in ttee tist on dy to ty tcaiy pand uto the simea form.
# Semed came m
#
#
# iter :5500, loss:33.850437
# rchilBebs Porseir, went him. Thes ssol, orsem. He brimed toms redid seiki got and al foold salerere pasvefyded had. He do ghen thorghe d€o sim leas hed th wis on Sastod sto go oSey. He ar clin tied th
#
#
# iter :6000, loss:32.630182
# himbed mormeedred ther and sol puthe siwne the Baba will hipktwen aid, sutut sa tai dorrro dirrtha hing the fortsen tweof troltied opin a bare dors and ther wadebb Aln cheed gll Wheeg whory wad Pofe h
#
#
# iter :6500, loss:31.286421
# res, He a teres capsai froxn on 2y sed unsen pusinty; wis and the do toy Bad murteintwed seed. aentwew in Per: he fobe tach wlb ole wale cand at wistid wark Por tied mim in iy diciteded nhoud si foimd
#
#
# iter :7000, loss:30.321135
# im. peneat Aed thels, thes then ip of mabn, moVe the toos hamd sain by them olt and cat aplisvend bm Shey thes, He theme to trey thel mure the towen Ses clite fo hor 20 Mi cloull cutesty, pas fist awy
#
#
# iter :7500, loss:29.450060
# eo whers fomerer Alimen. In fom welt ann cofeded t0e Baba hid am all thood: hy pheh â€“, akd mote well Ahin , clime samen theaght houlliyl. At aa drerory wist ixs Sesthen. He openghori Babarsimed by t
#
#
# iter :8000, loss:28.533012
# ed in wine hubar aw trthy sagh wit ild cied do toing then. The d oon clisted the the bnis inge him lo giw d wn thim:, whis copls wary wesbe sovese â€“ tien orsey the btin Alipg to limg ind hud int, me
#
#
# iter :8500, loss:27.603419
# penin whin Ale fror huve tu of am, wnwas wes in in Loun. He to and intlinh Afed in cuthe sack.
#
# Durtlo dor in in Po hin  n sorthe hirroof in a some saba t, mered ofiwed Cith the ware tother2.
#
#
# Thu th
#
#
# iter :9000, loss:26.889619
# e twandoto Opsopl his atsomerhut ho fiedt any wert lighind domtle Ihe t ama ca0' En hile!' Isehime!' sthe folpsed the , ahl on assuVess, ceas, hen Seasd ilba h fesias. Thed teorest, and made thighan b
#
#
# iter :9500, loss:26.009248
#  Bali daors unne la Eoxn clam bistaly He tow the mory anthe tien stys fisey: the toue the they so ol. Ond in in fothecutntes in ald he door sucbbessera Baba toog ighegs miser. Ther lion in plipn lo ch
#
#
# iter :10000, loss:25.382830
#  Ogitliy sith lis foued the door plin, ot togwthit the Ansdlingiid  ofe hirn cithe fornged Cad thin willtig the suildren, llo sabrin whed the the bary nestiigti towhed who gimed, âp ais in a nty d Cta
#
#
# iter :10500, loss:24.591897
# roo noun lom. TDead : wnortes, ay shild to coas rroad in in forg indybead doreve came wa dmerry mawd ow hitves, whoove a forest,iy they sone brhas on weat whoun. Jaba lurn of herE oxu digh thot wing t
#
#
# iter :11000, loss:23.926781
# 2' hindye hutheir hount in t at als an am. He towiss.
# , horsed with.
# Durwamam, we ptintha tis merest assiy Pislad bbud asmeing toyy. Whey seand th a sim. masn thim at irreis, mes foullersaad tied towe
#
#
# iter :11500, loss:23.443150
#  clitd the say dofut ount drorust sard thed the tud fil lipksbro bere haplind thir slim. Ad ind Basann as by An cuptiin had Ali Baba He ant cosbed thed aln bave hersing riclin them, theil. He theng do
#
#
# iter :12000, loss:23.038004
# a bavealy hed merring the dordlilb want a digetres, wan tge mior un fofes, wise tige Baba wicore Bart. Ale cofriget â€“ sild sack.
# Cang indid, whed ining pura tothe an. He ror in thed, anted lougbin i
#
#
# iter :12500, loss:22.448681
# ver Ange wroud hao pre thed in lorceAl whime hile horses, whe mawntad Ale harsek Cai Baba the tha treedrin & wa him, wen ple toan climbed his Persea tient dorteaut, horgis, whor and Alith then in in c
#
#
# iter :13000, loss:21.847749
# unted. Them afroo rxomeand forsing of ame!' ghe came houlurstow camhen oude lith fasbed, and wim tith utle same had on and the nass, and the capt onse
#
# prwe drexpcaild him. wad ant thill, he and the f
#
#
# iter :13500, loss:21.446437
# s the lormba soocy, chimeren by momaind thew benlit thoud fobangow bag thea rrenthe hing the mon moprriula baras of wedsey fosryerr, ought hime loaded the doryed â€“, ange frour pollabve tuo nther sam
#
#
# iter :14000, loss:20.908591
# n, Hered: wisin puthad the the bnthing the dorssad louk. One sasifed cawlled, ogh meabaple li maf inghe p in and cowas theng a drers. The broling plo li Baba simeen the horses wes baglin .ore Cth medh
#
#
# iter :14500, loss:20.396617
# d of ty of in Pe in a theng and Ali Baba, Ale war saut mao das beren agrehsim aga sut to thimt, abry lounhers, allt, and the then olom âne toberiid hill, was one tfees. The font on mobars, they psom h
#
#
# iter :15000, loss:19.885716
# ec rome ing. He One camha say coas seasd cotsam,
# pursamor whece sith utrout. mobres ats ma taoo ane the ducha ghem, whome!' hersmey ntiy siove am amo One to thell.
#
# Opno sa entiy twout lo tosen tiend
#
#
# iter :15500, loss:19.586561
# the ciok tisle the Bassa firs an ousthe Buf inyed has pese hurnaeg. Whes no forepse ansewrped fo tise themeirt Seca, an froma climlig intitging in call.
#
# Then Alith them. Une thelvece Albe came forest
#
#
# iter :16000, loss:18.970831
#  in anse frombent: Pepsairtren browd sat fasblt and of insis: hory. dhim ine tourte on. Ali Baba, wethe cook aswa an, sam and shig the tâobei fideere wa to ald fest, angei nick and chocurth baves the
#
#
# iter :16500, loss:18.419793
# ed in the froit droun t ant sist on is ange wad outheframed. They coulsich then toof selcaun lomed. Thes Ali Bala, douy, they un rursey. hes in Ali Bad iasint: fing oussam, wibe ad af them. Thilven ri
#
#
# iter :17000, loss:18.166984
# ane andt. He was in thech one the fien hifoack, the foutsam seis Ali haves, Ali Baba froun, and the uroot bo hime tow bood Celsing tiel, whimond extia to hime, and a come tea inga tia tine and lad ins
#
#
# iter :17500, loss:18.022274
# drercetwin wintot out of came Al, wele a loot ao duentrore sout to lo be ahe fror sa cad ald maye touc. Thiy alved. He totud and undlighty surresed ansted tout the towiy the cafrieg. rome sile cawn. w
#
#
# iter :18000, loss:17.602288
# they caf all , litgler hery lad Alick bedoin &y moud feir and feno ha vered dostiesand moug. hot Ali Baba one liclia ted by the sthy. B, and thin in an igh wersilh sawing the dus in the from perth chi
#
#
# iter :18500, loss:17.171771
# ved lo nein heing pomesa sawn. The kine homedring to a and the- nad ain Shas tham bever in thes pupen them, the bsop wadren in furs Alig, wad  y beclouryed, of mersime Ali B, an afesin &irt an bera al
#
#
# iter :19000, loss:16.802431
# ak, forty. shensin th o forseis more leasd were and in Seber
# peringam all pomesa frim, raed toth thes sofes.
#
# rowe lit and. Perla fid come to treedrene loceas, th oped in themen .u seothe suan Pe toud
#
#
# iter :19500, loss:16.384803
# , whersiSein, cam pecliabt. Ali Babas in agha fortied to tese Ali Baba wis mons of Sed, le bbed towy,we hursey. The forseverimen puin all conghen tisesed too bro D atsell.
#
# Titg, an thedler woutocest
#
#
# iter :20000, loss:16.101174
# nd of sem, wad met mamli Baba a, en che harsed faceing ortiger, al â€“
# rrestin and tien th mea, whory to plersam, chim oneng thing Ali Baba Alo Babalo dreed, withir opbas, Ali Babani Baba hhim on in a
#
#
# iter :20500, loss:15.934874
#  citkieg the siave oSean. One dae hichile hachire Dellizasf maly optaeg. Chen Porsion broPces wesedutwin weit alli Baba nint un buul purtee be as anin woursered in a sing to a sice sabm.
#
# O€ry Aliven
#
#
# iter :21000, loss:15.662819
# n hongeris bfrome, doud of but in Pecein r9im theithe fnim they brormichir. Wheis unpa, hours.
# Thed cam aledrerthe bena a tame!' Eve hit. was bre lanedris in atad, thell froutlid aed they werey baps.
#
#
# iter :21500, loss:15.390542
# em. Ali gother Ali Baba chianlle fer mountablingievas pllied, , fist aor sess faid to a bame froased Cass as, his allirs, out er he the bafean horene op openited At anthed in. Ali Babay thedair, and s
#
#
# iter :22000, loss:15.039923
# il. He tLact aid wold tTher â€buefewed coveile Ale Ali Baba. Cass, ang ts mea and cafe and chir and weil, das afe ought, and ing the door, and ther Alimen Pe atriy do rrerebârCob 1001 Nived saik was i
#
#
# iter :22500, loss:14.794985
# n they wert andy :  and cat, ong thim lom.
# He ware lous hile wid the lowming the door Ali Baba wad sa and docutta angiis whey come untholdrered thbllir diin Pithad in ain of itd one suage was loorysof
#
#
# iter :23000, loss:14.527406
#  undein wer eaves th of the cafrain & be herre Dearis whurre lay robbe haves.
#
# It wame hing othey them.
# , Clived. Ah mlasn 1y wilowed mebrocered in maade he towno apnt daid went a ind mas focli Baba h
#
#
# iter :23500, loss:14.353092
# bay, fithar asad ald ia thent home lith tsees curt tome to to the sopeney. shey role fismad touls fete ann and hen thit ted trim rrobbeguth ine fout their he limers a dicetwinen. He tilin putniadre on
#
#
# iter :24000, loss:14.024778
#  , lit taing wali Babn. He wewlo, the 2Vere tow clourseed thes the capdoredt Se chamen weli Babbed thet afrting indle hele herhed them with re assisodlith rowes me cath, chir sa the Baba has foulin th
#
#
# iter :24500, loss:13.736567
# s foryy ther sad â€“ and cetrim, waved them, wabrtroncealin hill.
# scourty tohb sife puade. He saw befety forestwen is hls, wes ir alf hourrer same purna mad in f op gots. hingot of sed and he to out o
#
#
# iter :25000, loss:13.553095
# n xShut if wis aid her, and sarn Sefe af ma â€“ Deali lised. One fay, Persiomen weted a onged to pusime!' herimere tabe. They tOce malf tow mabed in loprneort the cameacl Jand mighe tiir  losere.
# Duro
#
#
# iter :25500, loss:13.420065
# cbes be achouroedrent amy and horamd of maofre in thes ittaba, re and sas hamain. Ali Baba chomend, and same ounted to mailirgai tony uth traed, and heid town mead. He tother fadewont and seid somed i
#
#
# iter :26000, loss:13.057508
#
#
# 'in Pe hes to ard foom 100y Niven climert. Ill foty of or capchich robas stimerdy in oredt, wising thin ann.
#
# Then Ali Baba wee dourte puasd him teor. wn as baver by clirssheud the door and well â€“
#
#
# iter :26500, loss:12.825237
# swis and the fa in the dook out as brimin pand on by sirlid in in a psoop hind wim. widowe an the One camo forot open wotw fis m allV fo pmlb want tola Ct. Thim fong the brea wived the door unted shem
#
#
# iter :27000, loss:12.727847
# Ali Baba will ofey climbed the hasis, tore to by Ali Baba wases. Perail â€“ Mirsipk.
#
# â€“
#
# Atid wli loud they the s, and wint nocest opening a dine life puthisd nursebla d atle wait panhe thexus. Open
#
#
# iter :27500, loss:12.346115
#  tot mabstied they wetede outo t at oassted aa then. He comesectusase they foon Ali Baba aas, pea dors alling out at, ad a, shin orrees. swent and climblr, and herther angores mant toot the lirn. Th a
#
#
# iter :28000, loss:12.225520
# e form of the shere, do poutsic. He to dothis higstwasd silver dhein, whe clis ased man  if thic oof munceale!' Ither came uttlo drolly Ali Baba chin les.
#
# rt, and ind ba  Ali Baba sas atiey dot out o
#
#
# iter :28500, loss:11.899855
# e cafose sicli Babachis dut tora dnwitli hilved shil â€“ Mofe Et wis aussives.
#
# This Ver in of and wen. Ali Baba his is ben, thed and thed fot marrceirt.,  him wa, wwong the dord in main they capsay m
#
#
# iter :29000, loss:11.711449
# d the dora saw the doon whece ofe hurtut re hing towa das wad is hin &9 Mili Baba will cligh mimlrowem-a dâsaid, and shimd dilbac anr wifed, One achak sightise tortain &y sout. oâd intle wirshive-ged,
#
#
# iter :29500, loss:11.517821
# l mone tuillly ande thed  Ope ougted albt. Thes Sesameack, and wale ail livededreh. He wheris hs bendang the hagt.
#
# â€“
#
# The there, of tue ats as. hir in be ango out. a sime out re hand hurs rnorestod
#
#
# iter :30000, loss:11.405073
# haw bu: in the foreve all, peom an in lo chelbabn in angoted them, ingris ofe tle callome Ale half the dight hout beinged to plead whit on hoted by wist to ther hurted and ba the dooy do cimsild horss
#
#
# iter :30500, loss:11.192641
#  daed the forse stiorree baved fordedr, chin sor Alin with mut eim in bbecla h thend in lived. and llo One tast whe cain abad in hedower clome hich and sint opening pli hadeind it in, here fesebDurtie
#
#
# iter :31000, loss:11.267195
#  the tusfrs, anl she st alf ain fithewd, he anrist ber entin we treed gof anligh wefrs, the dags, and un rife astry, when. He in h wits on 29 Miling on hed tho brotherried thers, at they fose thei Bab
#
#
# iter :31500, loss:11.252602
# and laget aagit froobe.
# Then. Ont a mlime Ao sit werand of the thers, and came, bout of Ali Baba wion hountedustmile, hace Ali has buocade untes sals rromen, and to thichoty momome Berasist Sameind on
#
#
# iter :32000, loss:11.011036
# os ald erte pene wagat and cam alk a dighi they he a fomach he plble abe!' Mime upted sishe digf of the tigh wireng the holedrinto hime camli nigh wgle wed came out or hived. The capras bbea ad in ono
#
#
# iter :32500, loss:10.620273
# erreestiy sised foptain in. Ali Baba, horiy, the thed clo doir they wers and clild same, whold sim and wali got himhad uurd ore cawntly, whers, fore to by li cawlad comy stiantring mace hery on in lo
#
#
# iter :33000, loss:10.296155
#  an by in a doo men came hutwsed, when whblim. He ha the caonged to the captiin thilve the dofotyed, houd un but in in a choutselfowedle digh ro ir and toty uput he psall op in the trim the rock. The
#
#
# iter :33500, loss:10.437738
#  wnt and Ali Baba waled. He dors andre cuth lopcinves ptoop stlers and went stied to the door shut ots on hent to beid lived to hilve fing thiiver. Th foty openy of mersiid them, whom Afain thes came
#
#
# iter :34000, loss:10.111015
# borthe door hes in Pe the brasd dolbering in ineded bofeded towno dontain puts, sedsiantned n by wlot  Seshe door and ceiling. He saw a tulo forested do epsebrsaba tith pllo salf witutli ning the door
#
#
# iter :34500, loss:10.046042
# me tboop re ple theyrrist and whour lobbers. Oned they coma lis cloursedeid to B, again, and win  of out or treatlors rowned the the tor furnith. When they Ali Baba climbed hid iyrey che tla shy siuve
#
#
# iter :35000, loss:9.961234
# apsizamof ty onedy of out fo be h mas, put mas Ali Baba, Cavery Eli Babachis hlo chele heich hire t aore t Jand on mo the doop hith ont and atses, forust, if frin then ther cair love lith ofries comse
#
#
# iter :35500, loss:9.786068
# , alli thomberh.
# DeIsiutre cutheid shin ofe the troop dorgim, fete and ent exther plbusst, he siasd and ent, ha doom out firs, and silt and doveced ald ent to toth is liting wimianded in theo haclisso
#
#
# iter :36000, loss:9.680535
# ave fas faly his them, weclianly ciptle drea dow maced casd the came leas and the liss, and stimer puthed domest as be anfed, Ao the foo drealrowed mad Pe cairs.
#
# A tromed by tidhill!
# cCamedufnonghe f
#
#
# iter :36500, loss:9.549199
# ent, and lovesist, whicBaba ceild lives, and d fores. He wala redli gald be aid them anlo fing ong om irn be themliW froudaed towa tne cloun. Thoty sad rowned simed am, dseit ofray,, ow burses, pecham
#
#
# iter :37000, loss:9.880010
# ed bein watowe, dory of mbed sowed by Clameir hereirine dusthe sifed. he cia ther banghe plbed in a thur punt hise to h famad Eo for cofred. When then ang and the the cifeiived in in Pe sime and loun,
#
#
# iter :37500, loss:9.484957
# ndre. As me thes in lor 1a h rece wa a same roby, wall rass the capt on in. Ali Baba ororingat Anties. He went in were and one a lifnt dourserroom 1001 Nights ala, It anthe door shut in ther bad int a
#
#
# iter :38000, loss:9.127452
# naw Lafe and shem. He dtor irse out as haved an he came himlin the light fomli n brocli got hiss, and cein mas, fome un Seshing the w ofe angy the caight fete anvers.
# Th iid waed the door of ther sim
#
#
# iter :38500, loss:8.905244
# Ln on thed Ali Baba clits fagr, bechigstwen tifed. Ah withar, ca Babar hilvend to torrs ain wen on bafery soceca girt and sa hefed came out to be thed in the dords well lighted chim in the fores wamd
#
#
# iter :39000, loss:8.861241
# en the brse pasent ang the cafrorpastud four hutrorled &ow bening wood in in the tuto p an nfest wunt and finy mant basa do chem and children by clinbes rismeir in were and the soment, on whes pullin,
#
#
# iter :39500, loss:8.797270
# door chtsey, while. Ther ing thim to to ame unter aad t, out stoteet wing the door Af among the htwert of tot withome Alive, whicesabn. Theid awe un io forit dortis hlm, wand shilvey Ali Baba climber
#
#
# iter :40000, loss:8.841211
# ea a he the bagy bbe ta; wand shilver pllo paand op pichis the brer. Alim. Thei whurdee frell rhe broweled. The cafrorputhid iwsttoa inut arrsimtad indien Ali Baba came ut to mant gola Babas in f doas
#
#
# iter :40500, loss:8.629529
# , the pund h petiad, whe colk beraing indit, whery,. Using dome Alc in a trer as is all one, anged sista:  hichory and lad it be urpe out forg. Whe goocy a dreats. whe tnangod them to trerrigh ofrers,
#
#
# iter :41000, loss:8.276151
#  silit ol Ali Baba ther were and cliss, dook horsiston him in a him robe surtot climbed nocase wofe af amo b, and hacling the tle spla the urto ntor ald cameires, a dowes. The forse t bey sill lived t
#
#
# iter :41500, loss:8.279327
# pollimg diin ote. whed a choresewen â€“ rorgithe Baba wad in is,, in tne the sast of fe fagy y on ingin ad aod into a tuenth, was glo ditrirt Cans Sese!â€“
#
# That the could canghba chomgy, the cawnsim,
#
#
# iter :42000, loss:8.159514
#  toopent in leit lighoued in lighin iwed by the came, beves, and in out atsed mais and chit sin the bad op psares Sedein. The ha dill an tound out fiss oa tone tren by cadhasing thouthe door Ali Baba.
#
#
# iter :42500, loss:8.081148
# br imon 29 Mich rook mengy wloud of Ali Baba his fo tioop rords.
#
#
# At a siasd wimed in tein wnte. He comoid the door, be asam, and shiflieveid singad them, wang theird butt. wiled in the Deak. whe cam
#
#
# iter :43000, loss:7.986124
# in  frey tfombes an out t of out firs â€“ Morgethe in the there tall rours. fombes an â€“ Morghav Alives.
#
# In a drer rofed in in the tren rout and wesedrororsingad they roth.
# Pruenrighe pera hodried t
#
#
# iter :43500, loss:8.666571
#  ombeA fothals. Ali Baba was in the liod ut. One dowes puthirssine burted. An of moug. One wad in then Ali Baba, wis in themumerromin whed in a dame!â€verwis lich allo groom Ale Ah pith thieves, wedli
#
#
# iter :44000, loss:8.379450
# be rishbe Dordsek aple hars, the da loussey, out firted thilves Ali Baba hece ame and to a tula lors a dull, das and the wing the ats and n baning in tort and n lame pula, he bechin, Ah towane one tow
#
#
# iter :44500, loss:8.181921
# â€“ and caid the door, dissid toce he ass of moncle ro extroutting foot in in thecf ad of aed, antly dombed fed mad sheptly him. He did the ptot ne toon in th m haid intled come Ali Baba hid it the li
#
#
# iter :45000, loss:7.819331
#  cafn. Wy. Opeas, and the cain an ford sh optrot , my lighe da lorgeey. The namein, and climome Bertotwen Ali Baba ch op in the town. One day, when Ali tle uptad intle che saw a, them. They. Them.
#
# Th
#
#
# iter :45500, loss:7.523528
# ith. Thes ilid urot Ali Baba the prlm, uthe clowinea fothbror himlid inde unthe dowe tye the doop to torthe tich amoug oa torroe and hars, mone suoba home ut to a samling Ali n in tievins and cuthife
#
#
# iter :46000, loss:7.371923
# ing the bridled by in wout oon putsiy all pachen putly want to urtell. Thomy stimen by wir peroty hurrond hxcease framed by riseo onse pangabn ch He the foty of ty the forty of the clabledreit la wad
#
#
# iter :46500, loss:7.394622
# li do sime Ali Baba wifr en in aga, lich op in houllllowe dot Ali came ou to tishit aife out thim roop of dis outheresid io t to heves. ThPe and dio puts and Ali Baba slo be haslo, seli Baba hull mof
#
#
# iter :47000, loss:7.243406
# monces in maa drold sewas, the cloud out in by in ly kim, made atgha the cas louk.
#
# Then Ali Baba he fnenthe cas fill wale twelll
#
# Whersin ma wne fas bSertot ant door oa rrein llo d if merey forch wef
#
#
# iter :47500, loss:7.487126
#  browmer, wen bandes fithalo the cama maf they sthey ban Shing the doop forpsinl urtlers.
#
# Thapst sain wege wart therrilb forevet broing, fromby sofutn. He wesan â€“ Morpeng the dom counted shale Debb
#
#
# iter :48000, loss:7.595818
# meren by cliudsben, and toocs, and mant in of thersimg toor tpeas, berint ahd well a la newed on Sestam, and fort the clome harsiond forthe clin tea ding toor capra and colm. Cachtin open ororty. He l
#
#
# iter :48500, loss:7.284010
#  Janl. He wirs shid aga, childre!' out tSerfaed in an ame!' some Ali Baba tino brocli Baba cameis wesid weld anced in Persim ben Shid agas, werind out fist, and corngo dofe tle cuand ople hach of the
#
#
# iter :49000, loss:7.295374
# taled in thed. Them intle werge hirea doof hereid to marowens ont ando willo a ing in hived tw ut, and cilling in thega on by stile Deaking ingh. she sam at ty tfe furnout and lid in ple tien in Pere
#
#
# iter :49500, loss:7.230290
# hersiburty of ceisin momoming to the day, when the tree. Ah werend his hordsinthe ro tifn and wint to a dusaba dith nome and cuttiors. Durseis hecith on h lour, hemeir herell
#
# Ali ther came Al puutsam
#
#
# iter :50000, loss:6.912367
#  cailing the door and went and tell. He oncein couce Ala Bertothered bove sin, and selt hersedt, ore mang thewind h maad fabas, and mad brounted. They capli heng ther on 2u& was in Pert a atris rourth
#
#
# iter :50500, loss:6.715217
#  ounted by of the cast in by sime.
#
#
# In a down asd clin  wrom tofed ty out, and cherirsid it thim ad allece, an them, was Baba the plol, cad and went toro firesed them wed sorger silven, out. or in Ve
#
#
# iter :51000, loss:6.857057
# ve out fiss lo tay they ma wnin they come pamen â€“ Morgiana, ther caid thed tothe lloud colli forese Ber simead, hichin owe towene hile chiled by pise them porsrit, whllurthe dy a drom the door herss
#
#
# iter :51500, loss:7.176284
# rs, them an forss, afs on himled sing in in, wefr a do ther purs hutlomlid in a copcerllo
# I wling. He tist the dor money hurs ben at ty on &he urunted. Aly and sild and the doir hackin witham of in ca
#
#
# iter :52000, loss:6.994586
# s, Ali Baba took to be asfet, and they rown beves. At and feba fommbrobei two bentaband ofs fordegring the hing the door, bedeid of menin with opened riting in in ald ceildrend fema
# Why cisime!' he cl
#
#
# iter :52500, loss:6.677345
# s out thi forest, he soury untre door rove lith rache doon ott Seng amomen whors, weat. The fownt, he hiledried the daer horsed the plodursew hanclome Aa Babrecla
#  chow ofeid tofe and cols, ane durnie
#
#
# iter :53000, loss:6.429845
# nthe sime Af turne A in thim Ali Babs he themban Ali Baba, ans money. B, the brid, cont ens of amead, Peosty, buris him and thimowit wood rold coucaw reatde whoud on fous a dunt orede hurtirnt lome hi
#
#
# iter :53500, loss:6.265275
# tien. He to tiin them Alia rome hary tof mond the clomen whooc and werre couling ploor, hand of mad twimen whum fooc Ali Baba pling the thamen Ali Baba tay lid inta a troop of mening wimia duth on 29
#
#
# iter :54000, loss:6.224048
# . The town out ot en by sili Beyt oo roum thei Baba towhen â€“ Morg and turts.
#
# I tootre one gide hurast of ot he bridled intoaded has in lo bes wnor safrey baning of tugt of theAs of by sisind him an
#
#
# iter :54500, loss:6.084701
# rty to browsin dis is aivesroreasd golbachir, bed, and an by saesty and went frot Ali got. Ali twen be aed to a rice mawnt of was fing to tool putne hin friceand his as is him and doro thered bas in t
#
#
# iter :55000, loss:6.436126
# ly robherd hilltwh the door shes be the the surns A on 29 Mice Dery. The towe Deakin & Jana Elizardo downo him whe them. He werty, wall clo din anted, heckin with to ard wide the digh wiarthin wnorgot
#
#
# iter :55500, loss:6.416015
# an dien in thead cloupred ined by sher wing the daillowed the dong mo diesroon hoursean them, and cuthim tout olled wom At loale herist a ont unted wimiad here and res to thesed Cased the sthey wofe s
#
#
# iter :56000, loss:6.176866
#  broade the tiid to turt wint ind Ant mon manpain, and the drom persise h reaningle siwno horreed ther all wismout of fene out bro bith re a lont to there taed Ali Baba cam and lived ton is ass one fa
#
#
# iter :56500, loss:6.042726
# they ceild unfrirg the looked pan his oframe tawhen â€“ Morgha Bain Sest and the forest, he camen.
# They Ali Baba was in a dsom int ans bSuaps of mas curtula loxp rouand unte. will llad in a cloles cou
#
#
# iter :57000, loss:6.037443
# ves, hers, from Ali Baba. They un ig hand of man Ali Baba ney cout. hory tibllr
# oriin  Shed toeth tohe bun and wedtwen. The plole stror roun mad mlild cawling towar, wene a dowest, he saweded them wsa
#
#
# iter :57500, loss:5.800700
# thbr, his in a rereied indro in the doon he upund hid urrom: from ro boogiill re the tle sperse
# â€“ tasifreelly and sade twell ploud clo paad the door shule mounted forsis & cailing the in of sawd the
#
#
# iter :58000, loss:5.720128
#  outherssim afrieved to totas them plligh porimeas ulli Baba. Cassim on hy seit Ale the door shuted a forever by in the forme tawnto enomer pliprren Agi tow out opesime, cailing in the Deading the ba
#
#
# iter :58500, loss:5.765602
#  ntogeri das in the door horse. He was climbed downo in the ceilin &9 a ais wife and mount in a neighbour. Theris, whim untaid they were he digh fore sas ad a rouch fris outhers, one brocli Baba hemai
#
#
# iter :59000, loss:5.960603
# g of mbe ther say ban the browed. The forty, fisives by tobre hine Ali Baba wad to e cloog in heme dre ciang the dom rili tas rich nale Bert in and into a clouget ansire rxcle wsen we ut out the lle B
#
#
# iter :59500, loss:5.666536
# l they unfai grimbaf so toon wy onim. He tor, tthe duvesting wifa a dad them of cllo dreallo hurpathey peny the tha goty on niciass lopenit. He the hill puthit Cass amony the dod mounted br they loven
#
#
# iter :60000, loss:5.636591
# imlilve paptain of the captain they came out. As theed, whom 19 Ail purit lidh ong the stomy toba ploobe ass sought on doth mourse out to begain againd it in the tite pungain: dutseid:  Open Seathen c
#
#
# iter :60500, loss:5.494862
# ild ce forbe theirg. shed in a neighbourtead the hand of mad in Pergithand hiriat e cling the stimert his and silver in amara his the lith re aisedrill wersiaved by the in the tlolk were ans and lale,
#
#
# iter :61000, loss:5.906216
# d rasm they Ali Baba wad in the forest, and the towin of the forest He tortrouch aved in in:y dora dadeid in in the simedle t ame hard burseil love torurer coukdes an Seseclinh robberthe chesed wale h
#
#
# iter :61500, loss:5.756451
#  was trooDertwen burchandy on horseback, caim they cought out tewaclowbaing it th.
#
# â€“
#
# This and cair and chiline mad angain, oh poulas, all and outsedroo digh in firg wood hersios ille hich At simut
#
#
# iter :62000, loss:5.341606

# %%
rnn.predict(data_reader, 'I', 500)
# Out:
# "In a town in they came un a nain unt. ridh of and mand themurto a tice mabe toth in by came ut to masther, wint stoustind hid in a his the bagntied got iutwer, and said:  Open Sesame!' Evered ts a donge wull this ifrieved Ali to a tresas paclin mothed Ali Baba chut one and dormich oputill and the do a homed. At siatreid shim ant in VertWeas wno munt to the door horseat ass. He whowind the stand ne fore tloresind the door Ali Baba hidh wiunted theid tofe ald carn. Thein wes ale shed toth uples.\n\nI"
