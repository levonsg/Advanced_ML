# %% [markdown]
# ### Generating human faces with Adversarial Networks
# <img src="https://www.strangerdimensions.com/wp-content/uploads/2013/11/reception-robot.jpg" width=320>
# This time we'll train a neural net to generate plausible human faces in all their subtlty: appearance, expression, accessories, etc.
#
# Based on https://github.com/Lasagne/Recipes/pull/94 .

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
plt.rcParams.update({'axes.titlesize': 'small'})

from sklearn.datasets import load_digits
#The following line fetches you two datasets: images, usable for autoencoder training and attributes.
from lfw_dataset import fetch_lfw_dataset
data,attrs = fetch_lfw_dataset(dimx=36,dimy=36)

#preprocess faces
data = np.float32(data)/255.

IMG_SHAPE = data.shape[1:]

# %%
#print random image
plt.imshow(data[np.random.randint(data.shape[0])], cmap="gray", interpolation="none")

# %% [markdown]
# # Generative adversarial nets 101
#
# <img src="https://raw.githubusercontent.com/torch/torch.github.io/master/blog/_posts/images/model.png" width=320px height=240px>
#
# Deep learning is simple, isn't it?
# * build some network that generates the face (small image)
# * make up a __measure__ of __how good that face is__
# * optimize with gradient descent
#
#
# The only problem is: how can we tell well-generated faces from bad?
#
# __If we can't tell good faces from bad, we delegate it to yet another neural network!__
#
# That makes the two of them:
# * __G__enerator - takes random noize for inspiration and tries to generate a face sample.
#   * Let's call him __G__(z), where z is a gaussian noize.
# * __D__iscriminator - takes a face sample and tries to tell if it's great or fake.
#   * Predicts the probability of input image being a __real face__
#   * Let's call him __D__(x), x being an image.
#   * __D(x)__ is a predition for real image and __D(G(z))__ is prediction for the face made by generator.
#
# Before we dive into training them, let's construct the two networks.

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras import layers as L

# %%
CODE_SIZE = 256

generator = Sequential()
generator.add(L.InputLayer([CODE_SIZE],name='noise'))
generator.add(L.Dense(10*8*8, activation='elu'))

generator.add(L.Reshape((8,8,10)))
generator.add(L.Conv2DTranspose(64,kernel_size=(5,5),activation='elu'))
generator.add(L.Conv2DTranspose(64,kernel_size=(5,5),activation='elu'))
generator.add(L.UpSampling2D(size=(2,2)))
generator.add(L.Conv2DTranspose(32,kernel_size=3,activation='elu'))
generator.add(L.Conv2DTranspose(32,kernel_size=3,activation='elu'))
generator.add(L.Conv2DTranspose(32,kernel_size=3,activation='elu'))
generator.add(L.Conv2D(3,kernel_size=3,activation='elu'))
# generator.build(input_shape=(None, 256))
# generator.summary()

# %%
assert generator.output_shape[1:] == IMG_SHAPE, "generator must output an image of shape %s, but instead it produces %s"%(IMG_SHAPE,generator.output_shape[1:])

# %% [markdown]
# ### Discriminator
# Discriminator is your usual convolutional network with interlooping convolution and pooling layers

# %%
discriminator = Sequential()

discriminator.add(L.InputLayer(IMG_SHAPE))

discriminator.add(L.Dense(units=512,input_dim=28*28))
discriminator.add(L.Conv2D(64, (3,3), strides =(1,1), padding ='same', input_shape = [28,28,1]))
discriminator.add(L.LeakyReLU(0.2))
discriminator.add(L.Dropout(0.3))

discriminator.add(L.Flatten())
discriminator.add(L.Dense(256,activation='tanh'))
discriminator.add(L.Dense(2,activation=tf.nn.log_softmax))

# %% [markdown]
# # Training
#
# We train the two networks concurrently:
# * Train __discriminator__ to better distinguish real data from __current__ generator
# * Train __generator__ to make discriminator think generator is real
#
# ![img](gan.png)
#
# Training is done iteratively until discriminator is no longer able to find the difference (or until you run out of patience).
#
#
# ### Tricks:
# * You can find useful tricks here https://github.com/soumith/ganhacks

# %% [markdown]
# ### Auxilary functions
# Here we define a few helper functions that draw current data distributions and sample training batches.

# %%
def sample_noise_batch(bsize):
    return np.random.normal(size=(bsize, CODE_SIZE)).astype('float32')

def sample_data_batch(bsize):
    idxs = np.random.choice(np.arange(data.shape[0]), size=bsize)
    return data[idxs]

def sample_images(nrow,ncol, sharp=False):
    images = generator.predict(sample_noise_batch(bsize=nrow*ncol))
    if np.var(images)!=0:
        images = images.clip(np.min(data),np.max(data))
    for i in range(nrow*ncol):
        plt.subplot(nrow,ncol,i+1)
        if sharp:
            plt.imshow(images[i].reshape(IMG_SHAPE),cmap="gray", interpolation="none")
        else:
            plt.imshow(images[i].reshape(IMG_SHAPE),cmap="gray")
    plt.show()

def sample_probas(bsize):
    plt.title('Generated vs real data')
    plt.hist(np.exp(discriminator.predict(sample_data_batch(bsize)))[:,1],
             label='D(x)', alpha=0.5,range=[0,1])
    plt.hist(np.exp(discriminator.predict(generator.predict(sample_noise_batch(bsize))))[:,1],
             label='D(G(z))',alpha=0.5,range=[0,1])
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# ### Training
# Main loop.
# We just train generator and discriminator in a loop and draw results once every N iterations.

# %%
disc_optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
gen_optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

# %%
from IPython import display
from tqdm import tnrange
bsize=256

for epoch in tnrange(50000):
    real_data = sample_data_batch(bsize)
    noise = sample_noise_batch(bsize)

    for i in range(5):
    ########################
    #discriminator training#
    ########################
        with tf.GradientTape() as tape:
            logp_real = discriminator(real_data)
            generated_data = generator(noise)
            logp_gen = discriminator(generated_data)
    
            d_loss = -tf.reduce_mean(logp_real[:, 1] + logp_gen[:, 0])
            d_loss += tf.reduce_mean(discriminator.layers[-1].kernel ** 2)

        gradients = tape.gradient(d_loss, discriminator.trainable_weights)
        disc_optimizer.apply_gradients(zip(gradients, discriminator.trainable_weights))
    ########################
    ###generator training###
    ########################

    with tf.GradientTape() as tape:
        
        #g_loss = -tf.reduce_mean(logp_gen[:, 1])
        g_loss = -tf.reduce_mean(generator.layers[-1].kernel)

    gradients = tape.gradient(g_loss, generator.trainable_variables)
    gen_optimizer.apply_gradients(zip(gradients, generator.trainable_variables))
    print("###################################################################")
    print('g_loss', g_loss)
    print('d_loss', d_loss)
    print('epoch', epoch)
    print("*******************************************************************")
    if epoch %100==0:
        display.clear_output(wait=True)
        sample_images(2,3,True)
        sample_probas(1000)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 32/32 [==============================] - 0s 3ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 3ms/step
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.30131638, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009871802, shape=(), dtype=float32)
# epoch 301
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.30231622, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00096596865, shape=(), dtype=float32)
# epoch 302
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.30331606, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009689318, shape=(), dtype=float32)
# epoch 303
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.30431584, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009982663, shape=(), dtype=float32)
# epoch 304
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.30531573, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009792917, shape=(), dtype=float32)
# epoch 305
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.30631554, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009650134, shape=(), dtype=float32)
# epoch 306
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3073154, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00096044585, shape=(), dtype=float32)
# epoch 307
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.30831522, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00097406324, shape=(), dtype=float32)
# epoch 308
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.30931506, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00095692556, shape=(), dtype=float32)
# epoch 309
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3103149, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009556932, shape=(), dtype=float32)
# epoch 310
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.31131476, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00095238304, shape=(), dtype=float32)
# epoch 311
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3123146, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009595981, shape=(), dtype=float32)
# epoch 312
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.31331444, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0010364981, shape=(), dtype=float32)
# epoch 313
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.31431428, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0010132375, shape=(), dtype=float32)
# epoch 314
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3153141, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00094960287, shape=(), dtype=float32)
# epoch 315
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.31631395, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00096246775, shape=(), dtype=float32)
# epoch 316
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.31731376, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00094479835, shape=(), dtype=float32)
# epoch 317
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3183136, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00094413373, shape=(), dtype=float32)
# epoch 318
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.31931344, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00096350187, shape=(), dtype=float32)
# epoch 319
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.32031327, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0010857487, shape=(), dtype=float32)
# epoch 320
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3213131, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00097420876, shape=(), dtype=float32)
# epoch 321
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.32231295, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009488679, shape=(), dtype=float32)
# epoch 322
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3233128, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00094991014, shape=(), dtype=float32)
# epoch 323
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.32431263, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009507933, shape=(), dtype=float32)
# epoch 324
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3253125, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009617865, shape=(), dtype=float32)
# epoch 325
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3263123, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009471847, shape=(), dtype=float32)
# epoch 326
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.32731214, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00094860746, shape=(), dtype=float32)
# epoch 327
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.32831198, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009653659, shape=(), dtype=float32)
# epoch 328
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.32931182, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009428068, shape=(), dtype=float32)
# epoch 329
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.33031166, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009397577, shape=(), dtype=float32)
# epoch 330
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3313115, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009249557, shape=(), dtype=float32)
# epoch 331
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3323113, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009222838, shape=(), dtype=float32)
# epoch 332
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3333112, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00094403524, shape=(), dtype=float32)
# epoch 333
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.33431104, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009186097, shape=(), dtype=float32)
# epoch 334
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.33531088, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009224039, shape=(), dtype=float32)
# epoch 335
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3363107, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009309166, shape=(), dtype=float32)
# epoch 336
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.33731052, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009200991, shape=(), dtype=float32)
# epoch 337
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3383103, shape=(), dtype=float32)
# d_loss tf.Tensor(0.00091297936, shape=(), dtype=float32)
# epoch 338
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.33931023, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009223958, shape=(), dtype=float32)
# epoch 339
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.34031004, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0011589892, shape=(), dtype=float32)
# epoch 340
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.34130988, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009327229, shape=(), dtype=float32)
# epoch 341
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3423097, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0009230807, shape=(), dtype=float32)
# epoch 342
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.34330955, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0051457426, shape=(), dtype=float32)
# epoch 343
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.34430942, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0018698314, shape=(), dtype=float32)
# epoch 344
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.34530923, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0012260566, shape=(), dtype=float32)
# epoch 345
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.34630904, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0011352074, shape=(), dtype=float32)
# epoch 346
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3473089, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0011865066, shape=(), dtype=float32)
# epoch 347
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.34830877, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0012112356, shape=(), dtype=float32)
# epoch 348
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.34930858, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0012449923, shape=(), dtype=float32)
# epoch 349
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.35030842, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0012166747, shape=(), dtype=float32)
# epoch 350
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.35130826, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0012018346, shape=(), dtype=float32)
# epoch 351
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.35230812, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0011747364, shape=(), dtype=float32)
# epoch 352
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.35330793, shape=(), dtype=float32)
# d_loss tf.Tensor(0.001173204, shape=(), dtype=float32)
# epoch 353
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.35430774, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0012717072, shape=(), dtype=float32)
# epoch 354
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3553076, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0011304533, shape=(), dtype=float32)
# epoch 355
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.35630742, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0011219044, shape=(), dtype=float32)
# epoch 356
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3573073, shape=(), dtype=float32)
# d_loss tf.Tensor(0.001153612, shape=(), dtype=float32)
# epoch 357
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.35830712, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0010983483, shape=(), dtype=float32)
# epoch 358
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.35930696, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0011153821, shape=(), dtype=float32)
# epoch 359
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3603068, shape=(), dtype=float32)
# d_loss tf.Tensor(0.001347452, shape=(), dtype=float32)
# epoch 360
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.36130664, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0011052722, shape=(), dtype=float32)
# epoch 361
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.36230648, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0011029113, shape=(), dtype=float32)
# epoch 362
# *******************************************************************
# ...
# ###################################################################
# g_loss tf.Tensor(-0.3733047, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0010488617, shape=(), dtype=float32)
# epoch 373
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.37430453, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0010552412, shape=(), dtype=float32)
# epoch 374
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3753044, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0010596976, shape=(), dtype=float32)
# epoch 375
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.37630424, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0010389849, shape=(), dtype=float32)
# epoch 376
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.37730408, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0010464446, shape=(), dtype=float32)
# epoch 377
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.37830392, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0010390384, shape=(), dtype=float32)
# epoch 378
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.37930375, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0010903175, shape=(), dtype=float32)
# epoch 379
# *******************************************************************
# WARNING:tensorflow:Gradients do not exist for variables ['dense/kernel:0', 'dense/bias:0', 'conv2d_transpose/kernel:0', 'conv2d_transpose/bias:0', 'conv2d_transpose_1/kernel:0', 'conv2d_transpose_1/bias:0', 'conv2d_transpose_2/kernel:0', 'conv2d_transpose_2/bias:0', 'conv2d_transpose_3/kernel:0', 'conv2d_transpose_3/bias:0', 'conv2d_transpose_4/kernel:0', 'conv2d_transpose_4/bias:0', 'conv2d/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# ###################################################################
# g_loss tf.Tensor(-0.3803036, shape=(), dtype=float32)
# d_loss tf.Tensor(0.0012383449, shape=(), dtype=float32)
# epoch 380
# *******************************************************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 14
#       9 for i in range(5):
#      10 ########################
#      11 #discriminator training#
#      12 ########################
#      13     with tf.GradientTape() as tape:
# ---> 14         logp_real = discriminator(real_data)
#      15         generated_data = generator(noise)
#      16         logp_gen = discriminator(generated_data)
#
# File ~\.conda\envs\tf_39\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\.conda\envs\tf_39\lib\site-packages\keras\engine\training.py:490, in Model.__call__(self, *args, **kwargs)
#     486     super().__call__(inputs, *copied_args, **copied_kwargs)
#     488   layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 490 return super().__call__(*args, **kwargs)
#
# File ~\.conda\envs\tf_39\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\.conda\envs\tf_39\lib\site-packages\keras\engine\base_layer.py:1014, in Layer.__call__(self, *args, **kwargs)
#    1010   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1012 with autocast_variable.enable_auto_cast_variables(
#    1013     self._compute_dtype_object):
# -> 1014   outputs = call_fn(inputs, *args, **kwargs)
#    1016 if self._activity_regularizer:
#    1017   self._handle_activity_regularization(inputs, outputs)
#
# File ~\.conda\envs\tf_39\lib\site-packages\keras\utils\traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~\.conda\envs\tf_39\lib\site-packages\keras\engine\sequential.py:374, in Sequential.call(self, inputs, training, mask)
#     372   if not self.built:
#     373     self._init_graph_network(self.inputs, self.outputs)
# --> 374   return super(Sequential, self).call(inputs, training=training, mask=mask)
#     376 outputs = inputs  # handle the corner case where self.layers is empty
#     377 for layer in self.layers:
#     378   # During each iteration, `inputs` are the inputs to `layer`, and `outputs`
#     379   # are the outputs of `layer` applied to `inputs`. At the end of each
#     380   # iteration `inputs` is set to `outputs` to prepare for the next layer.
#
# File ~\.conda\envs\tf_39\lib\site-packages\keras\engine\functional.py:458, in Functional.call(self, inputs, training, mask)
#     439 @doc_controls.do_not_doc_inheritable
#     440 def call(self, inputs, training=None, mask=None):
#     441   """Calls the model on new inputs.
#     442
#     443   In this case `call` just reapplies
#    (...)
#     456       a list of tensors if there are more than one outputs.
#     457   """
# --> 458   return self._run_internal_graph(
#     459       inputs, training=training, mask=mask)
#
# File ~\.conda\envs\tf_39\lib\site-packages\keras\engine\functional.py:596, in Functional._run_internal_graph(self, inputs, training, mask)
#     593   continue  # Node is not computable, try skipping.
#     595 args, kwargs = node.map_arguments(tensor_dict)
# --> 596 outputs = node.layer(*args, **kwargs)
#     598 # Update tensor_dict.
#     599 for x_id, y in zip(node.flat_output_ids, tf.nest.flatten(outputs)):
#
# File ~\.conda\envs\tf_39\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\.conda\envs\tf_39\lib\site-packages\keras\engine\base_layer.py:1014, in Layer.__call__(self, *args, **kwargs)
#    1010   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1012 with autocast_variable.enable_auto_cast_variables(
#    1013     self._compute_dtype_object):
# -> 1014   outputs = call_fn(inputs, *args, **kwargs)
#    1016 if self._activity_regularizer:
#    1017   self._handle_activity_regularization(inputs, outputs)
#
# File ~\.conda\envs\tf_39\lib\site-packages\keras\utils\traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~\.conda\envs\tf_39\lib\site-packages\keras\layers\core\dense.py:224, in Dense.call(self, inputs)
#     221     outputs = tf.matmul(a=inputs, b=self.kernel)
#     222 # Broadcast kernel to inputs.
#     223 else:
# --> 224   outputs = tf.tensordot(inputs, self.kernel, [[rank - 1], [0]])
#     225   # Reshape the output back to the original ndim of the input.
#     226   if not tf.executing_eagerly():
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\math_ops.py:5120, in tensordot(a, b, axes, name)
#    5118 with ops.name_scope(name, "Tensordot", [a, b, axes]) as name:
#    5119   a = ops.convert_to_tensor(a, name="a")
# -> 5120   b = ops.convert_to_tensor(b, name="b")
#    5121   a_axes, b_axes = _tensordot_axes(a, axes)
#    5122   a_reshape, a_free_dims, a_free_dims_static = _tensordot_reshape(a, a_axes)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\ops.py:1638, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1629       raise RuntimeError(
#    1630           _add_error_prefix(
#    1631               f"Conversion function {conversion_func!r} for type "
#    (...)
#    1634               f"actual = {ret.dtype.base_dtype.name}",
#    1635               name=name))
#    1637 if ret is None:
# -> 1638   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1640 if ret is NotImplemented:
#    1641   continue
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\resource_variable_ops.py:2105, in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2104 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2105   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\resource_variable_ops.py:1467, in BaseResourceVariable._dense_var_to_tensor(***failed resolving arguments***)
#    1465   return self.read_value().op.inputs[0]
#    1466 else:
# -> 1467   return self.value()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\resource_variable_ops.py:582, in BaseResourceVariable.value(self)
#     580   return self._cached_value
#     581 with ops.colocate_with(None, ignore_existing=True):
# --> 582   return self._read_variable_op()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\resource_variable_ops.py:704, in BaseResourceVariable._read_variable_op(self, no_copy)
#     702       result = read_and_set_handle(no_copy)
#     703 else:
# --> 704   result = read_and_set_handle(no_copy)
#     706 if not context.executing_eagerly():
#     707   # Note that if a control flow context is active the input of the read op
#     708   # might not actually be the handle. This line bypasses it.
#     709   tape.record_operation(
#     710       "ReadVariableOp", [result], [self.handle],
#     711       backward_function=lambda x: [x],
#     712       forward_function=lambda x: [x])
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\resource_variable_ops.py:694, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     692 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     693   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 694 result = gen_resource_variable_ops.read_variable_op(
#     695     self.handle, self._dtype)
#     696 _maybe_set_handle_data(self._dtype, self.handle, result)
#     697 return result
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:524, in read_variable_op(resource, dtype, name)
#     522 if tld.is_eager:
#     523   try:
# --> 524     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     525       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     526     return _result
#     527   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=[16,24])
sample_images(16,8)

# %%
disc_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

for i in range(5):
    with tf.GradientTape() as tape:
        logp_real = discriminator(real_data)
        generated_data = generator(noise)
        logp_gen = discriminator(generated_data)

        d_loss = -tf.reduce_mean(logp_real[:, 1] + logp_gen[:, 0])
        d_loss += tf.reduce_mean(discriminator.layers[-1].kernel ** 2)

    gradients = tape.gradient(d_loss, discriminator.trainable_weights)
    disc_optimizer.apply_gradients(zip(gradients, discriminator.trainable_weights))
